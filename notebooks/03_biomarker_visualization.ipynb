# %% [markdown]
# # Speech2Health: Biomarker Visualization
#
# This notebook visualizes the identified biomarkers and their statistical significance.

# %%
import sys
import os

# Set the correct project root
project_root = "/Users/benedicthavor-abrahams/Desktop/Speech2health/speech-Processing/speech2health"
os.chdir(project_root)
sys.path.insert(0, project_root)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("seaborn-v0_8")
sns.set_palette("husl")

print(f"Project root: {project_root}")
print(f"Working directory: {os.getcwd()}")
# Out:
# Project root: /Users/benedicthavor-abrahams/Desktop/Speech2health/speech-Processing/speech2health
# Working directory: /Users/benedicthavor-abrahams/Desktop/Speech2health/speech-Processing/speech2health

# %% [markdown]
# ## 1. Load Biomarker Data

# %%
# Load significant biomarkers
biomarkers_df = pd.read_csv("results/biomarkers/significant_biomarkers.csv")
print(f"Total significant biomarkers: {len(biomarkers_df)}")
print(f"Top 10 biomarkers:")
biomarkers_df.head(10)
# Out:
# Total significant biomarkers: 35
# Top 10 biomarkers:
#       feature  mean_class0  mean_class1  std_class0  std_class1  \
# 0  Feature_71     0.294986     0.581471    0.465506    0.539275
# 1  Feature_50     0.133003    -0.189443    0.505322    0.411295
# 2  Feature_18     0.862601     2.262189    2.826875    4.266991
# 3  Feature_30    -0.598250    -1.469896    1.547338    1.895851
# 4  Feature_12    -0.077629     0.419995    0.828798    0.880681
# 5  Feature_73     0.303312     0.734807    0.784772    0.892833
# 6  Feature_28    -0.242237     0.168016    0.709474    0.562495
# 7  Feature_91    -0.308593    -0.569494    0.474433    0.521462
# 8  Feature_95     0.243791     0.527093    0.501683    0.521995
# 9  Feature_47    -0.288150    -0.530667    0.443701    0.486282
#
#    test_statistic   p_value  significant  cohens_d       test_type
# 0      385.000000  0.008259         True  0.568714  Mann-Whitney U
# 1        2.636882  0.010117         True -0.699884          t-test
# 2      396.000000  0.011703         True  0.386703  Mann-Whitney U
# 3      855.000000  0.012833         True -0.503728  Mann-Whitney U
# 4      400.000000  0.013241         True  0.581926  Mann-Whitney U
# 5      403.000000  0.013653         True  0.513353  Mann-Whitney U
# 6      402.000000  0.014075         True  0.640804  Mann-Whitney U
# 7      848.000000  0.014911         True -0.523370  Mann-Whitney U
# 8      408.500000  0.017002         True  0.553390  Mann-Whitney U
# 9      839.000000  0.017889         True -0.521007  Mann-Whitney U
