# %% [markdown]
# # Speech2Health: Model Comparison and Evaluation
#
# This notebook compares all trained models and analyzes their performance.

# %%
import sys
import os

# Set the correct project root
project_root = "/Users/benedicthavor-abrahams/Desktop/Speech2health/speech-Processing/speech2health"
os.chdir(project_root)
sys.path.insert(0, project_root)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("seaborn-v0_8")
sns.set_palette("husl")

print(f"Project root: {project_root}")
print(f"Working directory: {os.getcwd()}")
# Out:
# Project root: /Users/benedicthavor-abrahams/Desktop/Speech2health/speech-Processing/speech2health
# Working directory: /Users/benedicthavor-abrahams/Desktop/Speech2health/speech-Processing/speech2health

# %% [markdown]
# ## 1. Load Performance Metrics

# %%
# Load metrics
metrics_df = pd.read_csv("results/tables/all_metrics.csv")
print(f"Loaded metrics for {len(metrics_df)} model-split combinations")
print(f"Models: {metrics_df['model'].unique()}")
metrics_df.head(10)
# Out:
# Loaded metrics for 10 model-split combinations
# Models: ['Random Forest (Baseline)' 'Random Forest (Improved)'
#  'Random Forest (Fixed)' 'XGBoost' 'XGBoost (Improved)']
#    split  accuracy   auc_roc        f1  precision    recall  specificity  \
# 0  train  0.734375  0.878019  0.585366   0.521739  0.666667     0.760870
# 1    val  0.666667  0.522727  0.444444   0.400000  0.500000     0.727273
# 2  train  0.812500  0.834541  0.538462   0.875000  0.388889     0.978261
# 3    val  0.733333  0.522727  0.000000   0.000000  0.000000     1.000000
# 4  train  0.953125  0.980676  0.923077   0.857143  1.000000     0.934783
# 5    val  0.733333  0.545455  0.500000   0.500000  0.500000     0.818182
# 6  train  0.468750  1.000000  0.514286   0.346154  1.000000     0.260870
# 7    val  0.333333  0.386364  0.375000   0.250000  0.750000     0.181818
# 8  train  0.515625  0.885266  0.537313   0.367347  1.000000     0.326087
# 9    val  0.466667  0.590909  0.500000   0.333333  1.000000     0.272727
#
#                       model
# 0  Random Forest (Baseline)
# 1  Random Forest (Baseline)
# 2  Random Forest (Improved)
# 3  Random Forest (Improved)
# 4     Random Forest (Fixed)
# 5     Random Forest (Fixed)
# 6                   XGBoost
# 7                   XGBoost
# 8        XGBoost (Improved)
# 9        XGBoost (Improved)
